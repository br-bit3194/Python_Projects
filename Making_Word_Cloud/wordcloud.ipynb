# %%
import wikipedia
import numpy as np
from PIL import Image
# from wordcloud import WordCloud,STOPWORDS

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
def wikipediaFunc():    
    x=input("Enter the title: ")
    title=wikipedia.search(x)[0]
    page=wikipedia.page(title)
    text=page.content
    return text

#wikipediaFunc()
# file=open()
# text=""
# for x in file:
#     text+=x

text=wikipediaFunc()
stopwordset=set(STOPWORDS)
#stopwordset.remove("-")

background=np.array(Image.open(r"data:image/jpeg;base64,..."))
wc=WordCloud(background_color="black", max_words=1000, mask=background,
               stopwords=stopwordset, contour_width=4, contour_color='white')
    
#     background_color='white',mask=background,stopwords=stopwordset
#              ,inter)


wc.generate(text)
wc.to_file(r"F:\\wallpaper\\background6.png")
# Out:
# Enter the title: ai
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-0cd49b19e25f> in <module>
#      16 #stopwordset.remove("-")
#      17
# ---> 18 background=np.array(Image.open(r"data:image/jpeg;base64,..."))
#      19 wc=WordCloud(background_color="black", max_words=1000, mask=background,
#      20                stopwords=stopwordset, contour_width=4, contour_color='white')
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# OSError: [Errno 22] Invalid argument: 'data:image/jpeg;base64,...'

# %%
import matplotlib.pyplot as plt
img=plt.imread(r"F:\\wallpaper\\background6.png")
plt.imshow(img)
